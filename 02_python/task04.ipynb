# %%
try:
    first = int(input())
    second = int(input())

    result = first/second

except ValueError:
    print("エラー：数値を入力してください")
except ZeroDivisionError:
    print("エラー：0で割ることはできません")
else:
    print(f"計算結果: {result}")
# Out:
# 計算結果: 4.0
