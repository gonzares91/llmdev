# %%
num = int(input("数値を入力してください："))

if num * 1.1 >= 2000:
    print("送料は無料です")
    print(f"送料込税込価格は {int(num*1.1)}円です")
else:
    print("送料は350円です")
    print(f"送料込税込価格は {int(num*1.1) + 350}円です")
# Out:
# 送料は350円です
# 送料込税込価格は 2330円です
