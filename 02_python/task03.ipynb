# %%
investment = float(input("元金を入力してください："))
nenri = float(input("年利を入力してください："))

amount = investment
for i in range(10):
    amount = amount*(1+nenri/100)

print(f"10年後の金額:{round(amount,2)}")
# Out:
# 10年後の金額:1628.89
